# %% [markdown]
# # Big project
#
# ## Submission
#
# Submit solutions to https://forms.office.com/e/WexY7YraJb.
#
# 1.   Upload code in .ipynb file
# 2.   Upload a csv containing three columns:
# *    "ID": the ID of the instance (1, 2, 3, ...)
# *    "OBJ": the objective function value obtained
# *    "TIME": the execution time in seconds.
#
# ## Evaluation
#
# 1.   Gap w.r.t. optimal solutions
# 2.   Runtimes. Must be under 10 minutes for every instance. Execution times will be re-examined on a random basis.
#
# ## Deadline
#
# 12/01/2022 23:59 CET
#
# ## Other
#
# *   4 lab points just if you deliver something that works
# *   10 points based on the quality of method
# *   NO pre-coded libraries,
# *   NO genetic algorithms
# *   NO neural networks
# *   groups of max 3 students

# %% [markdown]
# ## Biogas plants location
#
# An association of $n$ farmers wants to open $p$ plants to produce energy from biogas.
# Each plant will be opened at a farm of a member of the association and will be powered with corn chopping purchased from the farm itself or from other neighboring farms.
#
# Each farm $i$ can provide at most $c_i$ tons of corn chopping, with a percentage of dry matter $a_i$. As you may know, dry matter is the key component of corn chopping used for biogas production. In order to maintain the quality of produced energy, each plant must burn a mixture of corn chopping with a percentage of dry matter between $k_{min}$ and $k_{max}$.
#
# At most one plant can be located in each farm, and every farm can sell its corn chopping to one and only one plant.
#
# Each farm $i$ is located at coordinates $x_i$ and $y_i$, representing respectively its latitude and longitude, and the cost of moving corn chopping from a farm $i$ to a farm $j$ is proportional to the euclidean distance between the two farms (it does not depend on the actual quantity moved, since the trucks used for this transportations are sufficiently big).
#
# Under such conditions, every plant produces $Q$ kWh of energy per ton of corn chopping burned. The energy produced by each plant will be fed into the national electricity system, at a unitary price of $b$ (€/kWh). Moreover, due to state regulations, each plant must not produce more than $M$ kWh of energy.
#
# You must locate $p$ plants among the available farms and assign the farms that will supply each plant, with the goal of maximizing the total revenues of the association.

# %% [markdown]
# ### Sets
# *   $I$ = set of farms
#
# ### Parameters
# *   $n$ = number of farms
# *   $p$ = number of plants to locate
# *   $b$ = revenue per unit of energy (€/kWh)
# *   $M$ = max energy production (kWh)
# *   $Q$ = energy produced by a ton of corn chopping (kWh/t)
# *   $k_{min} (k_{max})$ = min (max) percentage of dry matter for fermentation
# *   $a_i$ = percentage of dry matter in chopping from farm $i \in I$
# *   $c_i$ = tons of corn chopping available for each $i \in I$ (t)
# *   $x_i, y_i$ = coordinates of farm $i \in I$

# %%
# Branch and cut algorithm. Compute objective value first. Apply cutting plane algorithm since it's the fastest
# (less reliable). If there is an integer solution we're cool. Otherwise, apply the Branch and Cut algorithm 
# (create two sub-models). See if we have an integer solution --> Apply the cutting plane algorithm again. 
# All of this under the condiction that if we find a value under the incubent one, we stop.

# %%
# Clean files if present
# !rm instance_1.json
# !rm instance_1.txt

# Download instance_1 (both instance and solution) directly from Github
# !wget https://raw.githubusercontent.com/Daddeee/FOR_Labs_22-23/master/big-project/instances/instance_3.json
# !wget https://raw.githubusercontent.com/Daddeee/FOR_Labs_22-23/master/big-project/results/instance_3.txt
# Out:
# rm: instance_1.json: No such file or directory
# rm: instance_1.txt: No such file or directory
# --2023-01-09 13:51:09--  https://raw.githubusercontent.com/Daddeee/FOR_Labs_22-23/master/big-project/instances/instance_3.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1981 (1.9K) [text/plain]
# Saving to: 'instance_3.json.1'
#
# instance_3.json.1   100%[===================>]   1.93K  --.-KB/s    in 0s
#
# 2023-01-09 13:51:09 (18.7 MB/s) - 'instance_3.json.1' saved [1981/1981]
#
# --2023-01-09 13:51:10--  https://raw.githubusercontent.com/Daddeee/FOR_Labs_22-23/master/big-project/results/instance_3.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 18 [text/plain]
# Saving to: 'instance_3.txt.1'
#
# instance_3.txt.1    100%[===================>]      18  --.-KB/s    in 0s
#
# 2023-01-09 13:51:10 (1.23 MB/s) - 'instance_3.txt.1' saved [18/18]

# %%
# When using Colab, make sure you run this instruction beforehand
# !pip install --upgrade cffi==1.15.0 | grep -v 'already satisfied'
import importlib
import cffi
importlib.reload(cffi)
# !pip install mip | grep -v 'already satisfied'

# %%
#the optimal LP solution we found happens to be optimal for the ILP as well because it is integer and because the LP is a relaxation of the ILP problem.

# %%
# unsupported format string passed to NoneType.__format__

# %%
import json
import numpy as np
import mip

def recalculate_clusters(X, centroids, k):
    """ Recalculates the clusters """
    # Initiate empty clusters
    clusters = {}
    # Set the range for value of k (number of centroids)
    for i in range(k):
        clusters[i] = []
    # Setting the plot points using dataframe (X) and the vector norm (magnitude/length)
    for data in X:
        # Set up list of euclidian distance and iterate through
        euc_dist = []
        for j in range(k):
            euc_dist.append(np.linalg.norm(data - centroids[j]))
        # Append the cluster of data to the dictionary
        clusters[euc_dist.index(min(euc_dist))].append(data)
    return clusters    
 
def recalculate_centroids(centroids, clusters, k):
    """ Recalculates the centroid position based on the plot """ 
    for i in range(k):
        # Finds the average of the cluster at given index
        centroids[i] = np.average(clusters[i], axis=0)
    return centroids

def k_means_clustering(X, centroids={}, k=3, repeats=20):
    """ Calculates full k_means_clustering algorithm """
    for i in range(k):
        # Sets up the centroids based on the data
        centroids[i] = X[i]

    # Outputs the recalculated clusters and centroids 
    print(f'First and last of {repeats} iterations')
    for i in range(repeats):        
        clusters = recalculate_clusters(X, centroids, k)  
        centroids = recalculate_centroids(centroids, clusters, k)
        
    return clusters

def spanning_tree(k,points): # Inspired by laboratory 2.
    
    # ------------------ MODEL RESOLVING. SPANNING TREE.
    
    grid_size = 100 # size of the grid of points

    # Define the set of vertices of the graph as the list of numbers from 0 to k-1

    V = [i for i in range(k)]

    # Determine the distance between each point
    distance = np.linalg.norm(np.array(points) - np.array(points)[:,None], axis=-1)

    # Set of edges: note the condition that i<j (so we have pairs i,j but not j,i)
    # and especially the condition that prevents long arcs.

    # Ususally, in the litterature, we find a capital E related to the undirected edges.

    E = [(i,j) for i in V for j in V if i < j]
    
    # la partie de résolution du modèle. 
    
    # Generate the powerset of V
    # Contains all the subset of V
    from itertools import chain, combinations
    powerset = list(chain.from_iterable(combinations(V, r) for r in V))

    # combinations(V,1) = (0,), (1,),... (k-1), and so on...
    # f.i. powerset = [(0,), (1,)..., (0,1), ..., (0,1,2)] Until we consider all the subsets of V
    
    s = mip.Model()

    x = {(i,j): s.add_var(var_type=mip.BINARY) for (i,j) in E}

    for S in powerset:
        # We can only include subsets that are note empty.
        # Also, we don't want to include the set of all nodes.
        if len(S) > 0 and len(S) < k:
            s.add_constr(mip.xsum(x[i,j] for (i,j) in E 
                                if (i in S and j not in S)
                                or (j in S and i not in S)) >= 1)

    s.objective = mip.minimize(mip.xsum(distance[i,j]*x[i,j] for (i,j) in E))
    s.optimize()
    
    # ---- THE BEST NODE FROM THE PARTITION (THE ONE CLOSEST TO EVERY OTHER NODE OF THE PARTITION)
    
    sol = [(i,j) for (i,j) in E if x[i,j].x > 0.0001]
    print(f"{len(sol)} selected. {sol}")
   
    # If there is only one point in this cluster.
    if len(sol) == 0:
        i,j = points[0]
        to_add_constr = [i,j]
        return to_add_constr
    else:
        # From here we select the one who has the most arcs ingoing/outgoing.
        dic = {}
        for i in sol:
            for j in i:
                if j in dic.keys():
                    dic[j] = dic[j] + 1
                else:
                    dic[j] = 1
        max_value = max(dic.values()) # Select among all the farms, the ones with the highest number of arcs.
        print(dic)
        highest_farm = [k for k,v in dic.items() if v == max_value] # Put the farms with the highest value inside a list.
        # Choose the best node according their distance towards the other nodes of the same partition.
        coeff_list = [0]*k
        if len(highest_farm) > 1:
            for i in V:
                coeff_list[i] = sum(distance[i,:])
            i,j = points[coeff_list.index(min(coeff_list))]
            to_add_constr = [i,j]
        else:
            i,j = points[highest_farm[0]]
            to_add_constr = [i,j]
    
    return to_add_constr

# %%
# ------------------------- FUNCTIONS.

# Reads a .json instance and returns it in a dictionary
def load_instance(filename):
    with open(filename, 'r') as f:
        data = json.load(f)
    return data

# Reads a .txt result and returns it
def load_result(filename):
    with open(filename, 'r') as f:
        result = f.read()
    return float(result)

#def kmeans_clustering():

def x_var(m):
    # Returns an array of the variables x_ij of the model m.
    x_list = np.zeros((inst['n'],inst['n']))
    k = inst['n']
    for i in I:
        for j in M:
            x_list[i,j] = m.vars[k].x
            k = k+1
    return x_list

def print_result(m,x,y):

    import networkx as nx
    import matplotlib.pyplot as plt
    
    print(f"Profit: {m.objective_value:.2f} euro") # print the objective value of the model.

    print("Powerplants:") # For every powerplant opening we print the index of the candidate site j and the value of variable i.
    for j in M:
        if y[j].x > 1e-7:
            print(f"{j:3d} --> {y[j].x:7.3f}; farms: ", end='') # We print the index of the candidate site j and it's value y.
            for i in I: # For each powerplant.
                if x[i,j].x > 1e-7:
                    print(f"{i} ({x[i,j].x:.2f}); ", end='') # We then print the assign farms with the value of x[i,j].
            print('')
    # Visualize solution on graph
    pos_a = {f'A{j}': (pp_crd[j][0], pp_crd[j][1]) for j in M}
    pos_c = {f'C{i}': (f_crd[i][0], f_crd[i][1]) for i in I}
    
    nodepos = {**pos_a, **pos_c}
    
    # We visualize the solution on a graph. We will see light_blue powerplant (non-open powerplant). Yellow if they are open and are connected to assigned farms.
    
    g = nx.Graph()
    g.add_nodes_from([f'A{j}' for j in M])
    g.add_nodes_from([f'C{i}' for i in I])
    edges = [(f'A{j}', f'C{i}') for j in M for i in I if x[i,j].x > 0] 
    g.add_edges_from(edges)
    color = ['yellow' if y[j].x > 1e-6 else 'cyan' for j in M] + ['pink']*inst['n']
    plt.figure(1, figsize=(14,14))
    nx.draw_networkx(g, font_size=11, pos=nodepos, node_color=color)
    plt.show()

def solve(instance):
    # Compute the Euclidean distance between two points (fast version).
    # D_matrix = fast_distance_matrix(np.array(instance['points'])) # The euclidean distance matrix.
    D_matrix = np.linalg.norm(np.array(instance['points']) - np.array(instance['points'])[:,None], axis=-1)
    
    # -----
    
    # Under 10 farms. The branch & Bound technique is sufficient and fast enough to compute the solution.
    if instance['n'] > 10:
        clusters = k_means_clustering(np.array(instance['points']), k = instance['p'])
        # Rearrange the clusters for the spanning tree.
        a = {}
        for i in clusters:
            b = np.zeros((len(clusters[i]),2))
            for j in range(len(clusters[i])):
                b[j] = clusters[i][j]
            a[i] = b
        clusters = a
        
        # Spanning tree for each cluster we have. return the best node susceptible to have a powerplant
        # for each cluster.
        constraints = []
        for i in range(len(clusters)):
            to_add_constraints = spanning_tree(len(clusters[i]),clusters[i])
            print(to_add_constraints)
            i = instance['points'].index(to_add_constraints) # To retrieve which farm is it.
            constraints.append(i) # The farms with very high probability to have a powerplant are put in this list.
        print(constraints)
    else:
        constraints = []
    # -----
    
    # LP relaxation. Dual-bound. It is much faster to solve LP relax. rather than the IP.
    
    m = mip.Model()
    
    # ---- Add the VARIABLES.
    # As we did in laboratory 4, instead of storing them in a list, we store them in a dictionary with key (i,j).
    # Helpful for the display.
    y = {j: m.add_var(lb=0, ub=1, var_type=mip.BINARY) for j in M} # potential location of the farm.
    z = {(i,j): m.add_var(lb=0, ub=1, var_type=mip.BINARY) for i in I for j in M} # 1 if there is a link between farm/pp i&j.
    x = {(i,j): m.add_var() for i in I for j in M} # It is the chopping qty.
    
    # ---- Add the CONSTRAINTS.
    # We need to deploy a certain amount of fixed powerplants.
    m.add_constr(mip.xsum(y[j] for j in M) == instance['p'])
    
    # Each farm can be related to at most 1 powerplant.
    for i in I:
        m.add_constr(mip.xsum(z[i, j] for j in M) <= 1)
    
    # Production limit on the energy per powerplant.
    for j in M:
        m.add_constr(mip.xsum(instance['Q']*x[i, j] for i in I) <= instance['M'])
    
    # To respect the rightful dosage of crops to fuel a powerplant. Double constraints to linearize it.
    for j in M:
        m.add_constr(mip.xsum(x[i, j]*(instance['a'][i] - instance['kmax']) for i in I) <= 0)
        m.add_constr(mip.xsum(x[i, j]*(instance['a'][i] - instance['kmin']) for i in I) >= 0)
        
    for i in I:
        for j in M:
            m.add_constr(x[i,j] <= instance['c'][i]*z[i,j])
        
    # Last constraint is a consequence of the chosen binary variables.
    # Explanation is in labratory 4 but eventually if the binary variable 'y' is equal to 0 ==> leftside = 0.
    # We do not have any connexions with farms and an unexisting powerplant at location j.
    # On the other side, there is at most n farms connected to powerplant j. (Reminder: Multiple farms can be 
    # connected to a powerplant but a farm can only be connected to one and only one powerplant)
    for j in M:
        m.add_constr(mip.xsum(z[i, j] for i in I) <= instance['n']*y[j])
    
    # From the cutting_plane method laboratory 4.
    for i in I:
        for j in M:
            m.add_constr(z[i,j] <= y[j])
    
    # Add the constraint found in the clusters.
    for j in constraints:
        m.add_constr(y[j] == 1)

    # ---- Add the OBJECTIVE FUNCTION.
    
    # We want to maximize the Profits = Revenue - Costs. We have to parts for that.
    # Try to shorten the version of the objective function later. 
    
    m.objective = mip.maximize(
        mip.xsum(instance['Q']*instance['b']*x[i, j] for i in I for j in M) -
        mip.xsum(D_matrix[i, j]*z[i, j] for i in I for j in M)
    )
        
    m.optimize()
    print_result(m,x,y)
    
    return m.objective_value

# ------------------------- INITIALIZATION.

inst = load_instance("instance_3.json")
res = load_result("instance_3.txt")

# We suppose that we can have at most n powerplants such as p <= n.
I = range(inst['n']) # Set of n farms.
M = I # Set of number of farm candidates that can host a power plant.
    
#The potential future powerplants candidates and the locations of the farms.
pp_crd = inst['points']
f_crd = pp_crd

eps = 1e-3

# ------------------------- TREATMENT.

# %time obj = solve(inst)

gap = 100 * (obj - res) / res

print("result: {}".format(obj))
print("expected: {}".format(res))
print("gap: {}".format(gap))

# Let's print our model just right under this code.
# Out:
# First and last of 20 iterations
# Welcome to the CBC MILP Solver
# Version: Trunk
# Build Date: Oct 28 2021
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 15 (-15) rows, 10 (0) columns and 80 (-80) elements
# Clp1000I sum of infeasibilities 1.01253e-08 - average 6.75017e-10, 0 fixed columns
# Coin0506I Presolve 15 (0) rows, 10 (0) columns and 80 (0) elements
# Clp0029I End of values pass after 10 iterations
# Clp0014I Perturbing problem by 0.001% of 1.000004 - largest nonzero change 2.1059303e-05 ( 0.0010529652%) - largest zero change 1.2346901e-05
# Clp0000I Optimal - objective value 28.047046
# Clp0000I Optimal - objective value 28.047046
# Clp0000I Optimal - objective value 28.047046
# Coin0511I After Postsolve, objective 28.047046, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 28.04704642 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
#
# Starting MIP optimization
# 4 selected. [(0, 4), (1, 2), (1, 3), (2, 4)]
# {0: 1, 4: 2, 1: 2, 2: 2, 3: 1}
# [16.21174257599761, 91.05783163786192]
# Cgl0004I processed model has 15 rows, 10 columns (10 integer (10 of which binary)) and 80 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 4.762%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0038I Initial state - 5 integers unsatisfied sum - 2.5
# Cbc0038I Pass   1: suminf.    2.50000 (5) obj. 45.3427 iterations 4
# Cbc0038I Solution found of 90.6853
# Cbc0038I Rounding solution of 64.3474 is better than previous of 90.6853
#
# Cbc0038I Before mini branch and bound, 2 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 15 rows 10 columns, reduced to 15 rows 8 columns
# Cbc0038I Mini branch and bound improved solution from 64.3474 to 34.6052 (0.01 seconds)
# Cbc0038I Round again with cutoff of 33.9493
# Cbc0038I Pass   2: suminf.    2.50000 (7) obj. 33.9493 iterations 1
# Cbc0038I Pass   3: suminf.    1.98051 (4) obj. 33.9493 iterations 5
# Cbc0038I Pass   4: suminf.    0.99799 (4) obj. 33.9493 iterations 5
# Cbc0038I Pass   5: suminf.    1.73206 (4) obj. 33.9493 iterations 4
# Cbc0038I Pass   6: suminf.    1.89935 (5) obj. 33.9493 iterations 5
# Cbc0038I Pass   7: suminf.    1.11560 (3) obj. 33.9493 iterations 4
# Cbc0038I Pass   8: suminf.    1.50000 (4) obj. 33.9493 iterations 3
# Cbc0038I Pass   9: suminf.    1.22282 (4) obj. 33.9493 iterations 3
# Cbc0038I Pass  10: suminf.    1.50000 (4) obj. 33.9493 iterations 5
# Cbc0038I Pass  11: suminf.    0.00175 (2) obj. 33.9493 iterations 2
# Cbc0038I Solution found of 33.9377
# Cbc0038I Before mini branch and bound, 1 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 15 rows 10 columns, reduced to 15 rows 9 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I Round again with cutoff of 32.7595
# Cbc0038I Pass  12: suminf.    2.50000 (7) obj. 32.7595 iterations 0
# Cbc0038I Pass  13: suminf.    0.74936 (4) obj. 32.7595 iterations 6
# Cbc0038I Pass  14: suminf.    0.65086 (3) obj. 32.7595 iterations 1
# Cbc0038I Pass  15: suminf.    0.49281 (3) obj. 32.7595 iterations 4
# Cbc0038I Pass  16: suminf.    0.49281 (3) obj. 32.7595 iterations 2
# Cbc0038I Pass  17: suminf.    0.65086 (3) obj. 32.7595 iterations 3
# Cbc0038I Pass  18: suminf.    1.99781 (4) obj. 32.7595 iterations 2
# Cbc0038I Pass  19: suminf.    1.83566 (4) obj. 32.7595 iterations 3
# Cbc0038I Pass  20: suminf.    1.48588 (4) obj. 32.7595 iterations 4
# Cbc0038I Pass  21: suminf.    2.00000 (6) obj. 32.7595 iterations 2
# Cbc0038I Pass  22: suminf.    1.68522 (4) obj. 32.7595 iterations 3
# Cbc0038I Pass  23: suminf.    0.49281 (3) obj. 32.7595 iterations 3
# Cbc0038I Pass  24: suminf.    0.49281 (3) obj. 32.7595 iterations 2
# Cbc0038I Pass  25: suminf.    0.65086 (3) obj. 32.7595 iterations 3
# Cbc0038I Pass  26: suminf.    0.65086 (3) obj. 32.7595 iterations 2
# Cbc0038I Pass  27: suminf.    0.49281 (3) obj. 32.7595 iterations 4
# Cbc0038I Pass  28: suminf.    0.77516 (5) obj. 32.7595 iterations 3
# Cbc0038I Pass  29: suminf.    0.49281 (3) obj. 32.7595 iterations 1
# Cbc0038I Pass  30: suminf.    0.63902 (4) obj. 32.7595 iterations 1
# Cbc0038I Pass  31: suminf.    1.83566 (4) obj. 32.7595 iterations 2
# Cbc0038I Pass  32: suminf.    1.83566 (4) obj. 32.7595 iterations 0
# Cbc0038I Pass  33: suminf.    1.48588 (4) obj. 32.7595 iterations 4
# Cbc0038I Pass  34: suminf.    2.00000 (6) obj. 32.7595 iterations 2
# Cbc0038I Pass  35: suminf.    1.68522 (4) obj. 32.7595 iterations 3
# Cbc0038I Pass  36: suminf.    0.49281 (3) obj. 32.7595 iterations 3
# Cbc0038I Pass  37: suminf.    0.49281 (3) obj. 32.7595 iterations 2
# Cbc0038I Pass  38: suminf.    0.65086 (3) obj. 32.7595 iterations 3
# Cbc0038I Pass  39: suminf.    0.65086 (3) obj. 32.7595 iterations 2
# Cbc0038I Pass  40: suminf.    0.49281 (3) obj. 32.7595 iterations 4
# Cbc0038I Pass  41: suminf.    0.65086 (3) obj. 32.7595 iterations 3
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 0 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 15 rows 10 columns, reduced to 15 rows 10 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of 33.9377 - took 0.00 seconds
# Cbc0012I Integer solution of 33.937727 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0038I Full problem 15 rows 10 columns, reduced to 15 rows 7 columns
# Cbc0031I 3 added rows had average density of 6.6666667
# Cbc0013I At root node, 5 cuts changed objective from 28.047046 to 33.937727 in 2 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 5 column cuts (5 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 3 row cuts average 4.3 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (OddWheel) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (TwoMirCuts) - 3 row cuts average 4.3 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 8 (ZeroHalf) - 3 row cuts average 7.7 elements, 0 column cuts (0 active)  in 0.007 seconds - new frequency is 1
# Cbc0001I Search completed - best objective 33.93772723105072, took 7 iterations and 0 nodes (0.04 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.04
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Clp0000I Optimal - objective value 18.16779
# Coin0511I After Postsolve, objective 18.16779, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 18.16778976 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
#
# Starting MIP optimization
# 1 selected. [(0, 1)]
# {0: 1, 1: 1}
# [83.59678800325482, 61.02373321732014]
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc3007W No integer variables
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Clp0000I Optimal - objective value 23.749337
# Coin0511I After Postsolve, objective 23.749337, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 23.74933732 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
#
# Starting MIP optimization
# 1 selected. [(0, 1)]
# {0: 1, 1: 1}
# [51.047094682594704, 1.5791452211814438]
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc3007W No integer variables
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 7 (-7) rows, 6 (0) columns and 24 (-24) elements
# Clp1000I sum of infeasibilities 2.77928e-08 - average 3.97041e-09, 0 fixed columns
# Coin0506I Presolve 7 (0) rows, 6 (0) columns and 24 (0) elements
# Clp0029I End of values pass after 6 iterations
# Clp0000I Optimal - objective value 26.761028
# Clp0000I Optimal - objective value 26.761028
# Clp0000I Optimal - objective value 26.761028
# Coin0511I After Postsolve, objective 26.761028, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 26.76102769 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
#
# Starting MIP optimization
# 3 selected. [(0, 3), (1, 2), (2, 3)]
# {0: 1, 3: 2, 1: 1, 2: 2}
# [56.451897947453844, 99.73891432208869]
# Cgl0004I processed model has 7 rows, 6 columns (6 integer (6 of which binary)) and 24 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 7.692%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0038I Initial state - 4 integers unsatisfied sum - 2
# Cbc0038I Pass   1: suminf.    2.00000 (4) obj. 27.8539 iterations 1
# Cbc0038I Solution found of 55.7077
# Cbc0038I Rounding solution of 31.575 is better than previous of 55.7077
#
# Cbc0038I Before mini branch and bound, 0 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 7 rows 6 columns, reduced to 7 rows 6 columns
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I Round again with cutoff of 31.0935
# Cbc0038I Pass   2: suminf.    2.00000 (4) obj. 27.8539 iterations 0
# Cbc0038I Pass   3: suminf.    0.25879 (4) obj. 31.0935 iterations 4
# Cbc0038I Pass   4: suminf.    0.20274 (3) obj. 31.0935 iterations 1
# Cbc0038I Pass   5: suminf.    0.83312 (3) obj. 31.0935 iterations 3
# Cbc0038I Pass   6: suminf.    0.83312 (3) obj. 31.0935 iterations 1
# Cbc0038I Pass   7: suminf.    0.20274 (3) obj. 31.0935 iterations 4
# Cbc0038I Pass   8: suminf.    0.83312 (3) obj. 31.0935 iterations 3
# Cbc0038I Pass   9: suminf.    0.20274 (3) obj. 31.0935 iterations 2
# Cbc0038I Pass  10: suminf.    0.20274 (3) obj. 31.0935 iterations 0
# Cbc0038I Pass  11: suminf.    0.20274 (3) obj. 31.0935 iterations 0
# Cbc0038I Pass  12: suminf.    0.25879 (4) obj. 31.0935 iterations 1
# Cbc0038I Pass  13: suminf.    0.20274 (3) obj. 31.0935 iterations 1
# Cbc0038I Pass  14: suminf.    0.20274 (3) obj. 31.0935 iterations 0
# Cbc0038I Pass  15: suminf.    0.20274 (3) obj. 31.0935 iterations 0
# Cbc0038I Pass  16: suminf.    0.25879 (4) obj. 31.0935 iterations 1
# Cbc0038I Pass  17: suminf.    0.25879 (4) obj. 31.0935 iterations 0
# Cbc0038I Pass  18: suminf.    0.25879 (4) obj. 31.0935 iterations 0
# Cbc0038I Pass  19: suminf.    0.20274 (3) obj. 31.0935 iterations 1
# Cbc0038I Pass  20: suminf.    0.20274 (3) obj. 31.0935 iterations 0
# Cbc0038I Pass  21: suminf.    0.20274 (3) obj. 31.0935 iterations 0
# Cbc0038I Pass  22: suminf.    0.20274 (3) obj. 31.0935 iterations 0
# Cbc0038I Pass  23: suminf.    0.57704 (3) obj. 31.0935 iterations 1
# Cbc0038I Pass  24: suminf.    2.00000 (4) obj. 27.8539 iterations 4
# Cbc0038I Pass  25: suminf.    0.25879 (4) obj. 31.0935 iterations 4
# Cbc0038I Pass  26: suminf.    0.20274 (3) obj. 31.0935 iterations 1
# Cbc0038I Pass  27: suminf.    0.83312 (3) obj. 31.0935 iterations 3
# Cbc0038I Pass  28: suminf.    0.83312 (3) obj. 31.0935 iterations 1
# Cbc0038I Pass  29: suminf.    0.20274 (3) obj. 31.0935 iterations 4
# Cbc0038I Pass  30: suminf.    1.02807 (3) obj. 31.0935 iterations 1
# Cbc0038I Pass  31: suminf.    1.02807 (3) obj. 31.0935 iterations 0
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 0 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 7 rows 6 columns, reduced to 7 rows 6 columns
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of 31.575 - took 0.00 seconds
# Cbc0012I Integer solution of 31.574975 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0006I The LP relaxation is infeasible or too expensive
# Cbc0013I At root node, 0 cuts changed objective from 26.761028 to 26.761028 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 1 row cuts average 0.0 elements, 2 column cuts (2 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (OddWheel) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (TwoMirCuts) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 8 (ZeroHalf) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 31.57497495870631, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 3 (-3) rows, 3 (0) columns and 6 (-6) elements
# Clp1000I sum of infeasibilities 0 - average 0, 0 fixed columns
# Coin0506I Presolve 3 (0) rows, 3 (0) columns and 6 (0) elements
# Clp0029I End of values pass after 3 iterations
# Clp0000I Optimal - objective value 43.538083
# Clp0000I Optimal - objective value 43.538083
# Clp0000I Optimal - objective value 43.538083
# Coin0511I After Postsolve, objective 43.538083, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 43.53808346 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
#
# Starting MIP optimization
# 2 selected. [(0, 1), (0, 2)]
# {0: 2, 1: 1, 2: 1}
# [16.287753326976727, 12.663477969083758]
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0004I processed model has 1 rows, 3 columns (3 integer (3 of which binary)) and 3 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 28.571%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of 43.5636
# Cbc0038I Before mini branch and bound, 3 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of 43.5636 - took 0.00 seconds
# Cbc0012I Integer solution of 43.563611 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective 43.56361072565448, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 7 (-7) rows, 6 (0) columns and 24 (-24) elements
# Clp1000I sum of infeasibilities 2.24493e-10 - average 3.20704e-11, 0 fixed columns
# Coin0506I Presolve 7 (0) rows, 6 (0) columns and 24 (0) elements
# Clp0029I End of values pass after 6 iterations
# Clp0000I Optimal - objective value 23.774737
# Clp0000I Optimal - objective value 23.774737
# Clp0000I Optimal - objective value 23.774737
# Coin0511I After Postsolve, objective 23.774737, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 23.7747371 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
#
# Starting MIP optimization
# 3 selected. [(0, 1), (1, 2), (2, 3)]
# {0: 1, 1: 2, 2: 2, 3: 1}
# [34.976921269998186, 70.25237197137582]
# [19, 10, 2, 11, 4, 8]
# Cgl0004I processed model has 7 rows, 6 columns (6 integer (6 of which binary)) and 24 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 7.692%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0038I Initial state - 4 integers unsatisfied sum - 2
# Cbc0038I Pass   1: suminf.    2.00000 (4) obj. 23.9676 iterations 1
# Cbc0038I Solution found of 47.9352
# Cbc0038I Rounding solution of 24.4762 is better than previous of 47.9352
#
# Cbc0038I Before mini branch and bound, 0 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 7 rows 6 columns, reduced to 7 rows 6 columns
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I Round again with cutoff of 24.406
# Cbc0038I Pass   2: suminf.    2.00000 (4) obj. 23.9676 iterations 0
# Cbc0038I Pass   3: suminf.    0.27618 (4) obj. 24.406 iterations 4
# Cbc0038I Pass   4: suminf.    0.20757 (3) obj. 24.406 iterations 1
# Cbc0038I Pass   5: suminf.    1.19713 (3) obj. 24.406 iterations 2
# Cbc0038I Pass   6: suminf.    1.19713 (3) obj. 24.406 iterations 1
# Cbc0038I Pass   7: suminf.    0.20757 (3) obj. 24.406 iterations 4
# Cbc0038I Pass   8: suminf.    1.83603 (4) obj. 24.406 iterations 2
# Cbc0038I Pass   9: suminf.    1.83603 (4) obj. 24.406 iterations 0
# Cbc0038I Pass  10: suminf.    1.83603 (4) obj. 24.406 iterations 0
# Cbc0038I Pass  11: suminf.    1.80225 (4) obj. 24.406 iterations 2
# Cbc0038I Pass  12: suminf.    1.80225 (4) obj. 24.406 iterations 0
# Cbc0038I Pass  13: suminf.    1.94766 (5) obj. 24.406 iterations 2
# Cbc0038I Pass  14: suminf.    1.71527 (4) obj. 24.406 iterations 3
# Cbc0038I Pass  15: suminf.    1.19713 (3) obj. 24.406 iterations 2
# Cbc0038I Pass  16: suminf.    1.19713 (3) obj. 24.406 iterations 1
# Cbc0038I Pass  17: suminf.    0.20757 (3) obj. 24.406 iterations 4
# Cbc0038I Pass  18: suminf.    0.20757 (3) obj. 24.406 iterations 0
# Cbc0038I Pass  19: suminf.    0.27618 (4) obj. 24.406 iterations 1
# Cbc0038I Pass  20: suminf.    0.20757 (3) obj. 24.406 iterations 1
# Cbc0038I Pass  21: suminf.    1.19713 (3) obj. 24.406 iterations 2
# Cbc0038I Pass  22: suminf.    1.19713 (3) obj. 24.406 iterations 1
# Cbc0038I Pass  23: suminf.    0.20757 (3) obj. 24.406 iterations 4
# Cbc0038I Pass  24: suminf.    1.83603 (4) obj. 24.406 iterations 2
# Cbc0038I Pass  25: suminf.    1.83603 (4) obj. 24.406 iterations 0
# Cbc0038I Pass  26: suminf.    1.83603 (4) obj. 24.406 iterations 0
# Cbc0038I Pass  27: suminf.    1.80225 (4) obj. 24.406 iterations 2
# Cbc0038I Pass  28: suminf.    1.80225 (4) obj. 24.406 iterations 0
# Cbc0038I Pass  29: suminf.    1.85757 (5) obj. 24.406 iterations 2
# Cbc0038I Pass  30: suminf.    1.50000 (4) obj. 24.406 iterations 3
# Cbc0038I Pass  31: suminf.    0.20757 (3) obj. 24.406 iterations 2
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 0 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 7 rows 6 columns, reduced to 7 rows 6 columns
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of 24.4762 - took 0.00 seconds
# Cbc0012I Integer solution of 24.476219 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0006I The LP relaxation is infeasible or too expensive
# Cbc0013I At root node, 0 cuts changed objective from 23.774737 to 23.774737 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 1 row cuts average 0.0 elements, 2 column cuts (2 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (OddWheel) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (TwoMirCuts) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 8 (ZeroHalf) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 24.47621901205081, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Starting solution of the Linear programming relaxation problem using Dual Simplex
#
# Coin0506I Presolve 158 (-749) rows, 240 (-580) columns and 720 (-2926) elements
# Clp0000I Optimal - objective value 2358085.4
# Coin0511I After Postsolve, objective 2358085.4, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 2358085.449 - 271 iterations time 0.002, Presolve 0.00
#
# Starting MIP optimization
# Cgl0008I 20 inequality constraints converted to equality constraints
# Cgl0005I 20 SOS with 140 members
# Cgl0004I processed model has 158 rows, 260 columns (140 integer (140 of which binary)) and 740 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 0.413%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0038I Initial state - 13 integers unsatisfied sum - 2.73948
# Cbc0038I Pass   1: suminf.    0.00000 (0) obj. -1.78536e+06 iterations 39
# Cbc0038I Solution found of -1.78536e+06
# Cbc0038I Relaxing continuous gives -2.11657e+06
# Cbc0038I Before mini branch and bound, 108 integers at bound fixed and 122 continuous
# Cbc0038I Full problem 158 rows 260 columns, reduced to 22 rows 21 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I Round again with cutoff of -2.14072e+06
# Cbc0038I Pass   2: suminf.    0.10017 (4) obj. -2.14072e+06 iterations 23
# Cbc0038I Pass   3: suminf.    1.07650 (7) obj. -2.14072e+06 iterations 21
# Cbc0038I Pass   4: suminf.    0.41042 (4) obj. -2.14072e+06 iterations 21
# Cbc0038I Pass   5: suminf.    1.00000 (3) obj. -2.14072e+06 iterations 22
# Cbc0038I Pass   6: suminf.    0.65369 (2) obj. -2.14072e+06 iterations 2
# Cbc0038I Pass   7: suminf.    0.39375 (2) obj. -2.14072e+06 iterations 5
# Cbc0038I Pass   8: suminf.    0.00000 (0) obj. -2.14072e+06 iterations 7
# Cbc0038I Solution found of -2.14072e+06
# Cbc0038I Relaxing continuous gives -2.1446e+06
# Cbc0038I Before mini branch and bound, 100 integers at bound fixed and 114 continuous
# Cbc0038I Full problem 158 rows 260 columns, reduced to 40 rows 41 columns
# Cbc0038I Mini branch and bound improved solution from -2.1446e+06 to -2.15402e+06 (0.02 seconds)
# Cbc0038I Round again with cutoff of -2.19483e+06
# Cbc0038I Pass   9: suminf.    0.32127 (4) obj. -2.19483e+06 iterations 0
# Cbc0038I Pass  10: suminf.    1.06058 (9) obj. -2.19483e+06 iterations 21
# Cbc0038I Pass  11: suminf.    0.64575 (6) obj. -2.19483e+06 iterations 10
# Cbc0038I Pass  12: suminf.    1.04177 (6) obj. -2.19483e+06 iterations 27
# Cbc0038I Pass  13: suminf.    0.77139 (3) obj. -2.19483e+06 iterations 8
# Cbc0038I Pass  14: suminf.    0.01140 (2) obj. -2.19483e+06 iterations 7
# Cbc0038I Pass  15: suminf.    0.01140 (2) obj. -2.19483e+06 iterations 2
# Cbc0038I Pass  16: suminf.    0.20553 (2) obj. -2.19483e+06 iterations 6
# Cbc0038I Pass  17: suminf.    0.00000 (0) obj. -2.19483e+06 iterations 12
# Cbc0038I Solution found of -2.19483e+06
# Cbc0038I Relaxing continuous gives -2.20403e+06
# Cbc0038I Before mini branch and bound, 97 integers at bound fixed and 110 continuous
# Cbc0038I Full problem 158 rows 260 columns, reduced to 45 rows 47 columns
# Cbc0038I Mini branch and bound improved solution from -2.20403e+06 to -2.23986e+06 (0.03 seconds)
# Cbc0038I Round again with cutoff of -2.27533e+06
# Cbc0038I Pass  18: suminf.    0.73935 (9) obj. -2.27533e+06 iterations 18
# Cbc0038I Pass  19: suminf.    1.30384 (8) obj. -2.27533e+06 iterations 45
# Cbc0038I Pass  20: suminf.    0.52066 (2) obj. -2.27533e+06 iterations 23
# Cbc0038I Pass  21: suminf.    0.29294 (2) obj. -2.27533e+06 iterations 2
# Cbc0038I Pass  22: suminf.    0.98277 (6) obj. -2.27533e+06 iterations 28
# Cbc0038I Pass  23: suminf.    0.29882 (4) obj. -2.27533e+06 iterations 22
# Cbc0038I Pass  24: suminf.    0.24825 (2) obj. -2.27533e+06 iterations 11
# Cbc0038I Pass  25: suminf.    0.95456 (2) obj. -2.27533e+06 iterations 19
# Cbc0038I Pass  26: suminf.    3.69562 (11) obj. -2.27533e+06 iterations 70
# Cbc0038I Pass  27: suminf.    1.08279 (5) obj. -2.27533e+06 iterations 18
# Cbc0038I Pass  28: suminf.    1.93628 (5) obj. -2.27533e+06 iterations 13
# Cbc0038I Pass  29: suminf.    1.21554 (6) obj. -2.27533e+06 iterations 39
# Cbc0038I Pass  30: suminf.    1.11794 (5) obj. -2.27533e+06 iterations 13
# Cbc0038I Pass  31: suminf.    1.43023 (6) obj. -2.27533e+06 iterations 12
# Cbc0038I Pass  32: suminf.    0.96748 (5) obj. -2.27533e+06 iterations 19
# Cbc0038I Pass  33: suminf.    1.15794 (4) obj. -2.27533e+06 iterations 19
# Cbc0038I Pass  34: suminf.    1.48939 (7) obj. -2.27533e+06 iterations 38
# Cbc0038I Pass  35: suminf.    0.97499 (3) obj. -2.27533e+06 iterations 17
# Cbc0038I Pass  36: suminf.    0.83425 (3) obj. -2.27533e+06 iterations 7
# Cbc0038I Pass  37: suminf.    1.01961 (5) obj. -2.27533e+06 iterations 13
# Cbc0038I Pass  38: suminf.    0.93246 (3) obj. -2.27533e+06 iterations 9
# Cbc0038I Pass  39: suminf.    2.07467 (11) obj. -2.27533e+06 iterations 51
# Cbc0038I Pass  40: suminf.    1.21876 (8) obj. -2.27533e+06 iterations 20
# Cbc0038I Pass  41: suminf.    1.26382 (5) obj. -2.27533e+06 iterations 19
# Cbc0038I Pass  42: suminf.    0.73084 (6) obj. -2.27533e+06 iterations 21
# Cbc0038I Pass  43: suminf.    2.00542 (8) obj. -2.27533e+06 iterations 20
# Cbc0038I Pass  44: suminf.    1.16891 (7) obj. -2.27533e+06 iterations 10
# Cbc0038I Pass  45: suminf.    1.29982 (7) obj. -2.27533e+06 iterations 14
# Cbc0038I Pass  46: suminf.    1.05954 (7) obj. -2.27533e+06 iterations 12
# Cbc0038I Pass  47: suminf.    1.17076 (6) obj. -2.27533e+06 iterations 12
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 47 integers at bound fixed and 58 continuous
# Cbc0038I Full problem 158 rows 260 columns, reduced to 109 rows 144 columns - 15 fixed gives 48, 65 - ok now
# Cbc0038I Full problem 158 rows 260 columns, reduced to 48 rows 65 columns
# Cbc0038I Mini branch and bound did not improve solution (0.05 seconds)
# Cbc0038I After 0.05 seconds - Feasibility pump exiting with objective of -2.23986e+06 - took 0.04 seconds
# Cbc0012I Integer solution of -2239858.3 found by feasibility pump after 0 iterations and 0 nodes (0.05 seconds)
# Cbc0038I Full problem 158 rows 260 columns, reduced to 33 rows 38 columns
# Cbc0031I 36 added rows had average density of 67.444444
# Cbc0013I At root node, 36 cuts changed objective from -2358085.4 to -2357913 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.034 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 974 row cuts average 210.5 elements, 0 column cuts (0 active)  in 0.094 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.056 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.005 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (OddWheel) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.008 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (MixedIntegerRounding2) - 819 row cuts average 29.2 elements, 0 column cuts (0 active)  in 0.068 seconds - new frequency is 1
# Cbc0014I Cut generator 6 (FlowCover) - 75 row cuts average 8.5 elements, 0 column cuts (0 active)  in 0.028 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (TwoMirCuts) - 87 row cuts average 137.0 elements, 0 column cuts (0 active)  in 0.030 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, -2239858.3 best solution, best possible -2357913 (0.62 seconds)
# Cbc0012I Integer solution of -2266360.9 found by DiveCoefficient after 3605 iterations and 3 nodes (0.68 seconds)
# Cbc0012I Integer solution of -2316058.7 found by DiveCoefficient after 3786 iterations and 3 nodes (0.71 seconds)
# Cbc0038I Full problem 158 rows 260 columns, reduced to 51 rows 63 columns
# Cbc0012I Integer solution of -2349967.1 found by RINS after 6084 iterations and 41 nodes (0.93 seconds)
# Cbc0038I Full problem 158 rows 260 columns, reduced to 52 rows 62 columns
# Cbc0012I Integer solution of -2350934.3 found by RINS after 8596 iterations and 91 nodes (1.16 seconds)
# Cbc0010I After 158 nodes, 40 on tree, -2350934.3 best solution, best possible -2357913 (1.32 seconds)
# Cbc0038I Full problem 158 rows 260 columns, reduced to 59 rows 66 columns
# Cbc0012I Integer solution of -2351086.5 found by RINS after 13360 iterations and 200 nodes (1.44 seconds)
# Cbc0038I Full problem 158 rows 260 columns, reduced to 59 rows 69 columns
# Cbc0012I Integer solution of -2352569.7 found by DiveCoefficient after 22064 iterations and 420 nodes (1.98 seconds)
# Cbc0010I After 433 nodes, 89 on tree, -2352569.7 best solution, best possible -2357913 (2.03 seconds)
# Cbc0038I Full problem 158 rows 260 columns, reduced to 44 rows 53 columns
# Cbc0012I Integer solution of -2352838.6 found by RINS after 27904 iterations and 600 nodes (2.39 seconds)
# Cbc0038I Full problem 158 rows 260 columns, reduced to 42 rows 52 columns
# Cbc0012I Integer solution of -2352899.6 found by RINS after 30449 iterations and 700 nodes (2.55 seconds)
# Cbc0038I Full problem 158 rows 260 columns, reduced to 45 rows 52 columns
# Cbc0012I Integer solution of -2353041.9 found by RINS after 32401 iterations and 800 nodes (2.70 seconds)
# Cbc0010I After 819 nodes, 164 on tree, -2353041.9 best solution, best possible -2357913 (2.73 seconds)
# Cbc0012I Integer solution of -2355212.4 found by rounding after 34634 iterations and 891 nodes (2.84 seconds)
# Cbc0038I Full problem 158 rows 260 columns, reduced to 56 rows 69 columns
# Cbc0016I Integer solution of -2355525.9 found by strong branching after 36807 iterations and 958 nodes (3.02 seconds)
# Cbc0038I Full problem 158 rows 260 columns, reduced to 61 rows 71 columns
# Cbc0012I Integer solution of -2356121.5 found by RINS after 38530 iterations and 1000 nodes (3.18 seconds)
# Cbc0038I Full problem 158 rows 260 columns, reduced to 71 rows 85 columns
# Cbc0010I After 1135 nodes, 73 on tree, -2356121.5 best solution, best possible -2357913 (3.43 seconds)
# Cbc0038I Full problem 158 rows 260 columns, reduced to